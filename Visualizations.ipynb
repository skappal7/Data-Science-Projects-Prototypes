# %% [markdown]
# <a href="https://colab.research.google.com/github/skappal7/Coursera-Data-science-Project/blob/master/Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Interesting Visualizations Using Seaborn**
# ![alt text](https://skappal7.files.wordpress.com/2017/08/datadojo7.jpg?w=100)

# %% [markdown]
# **Importing all the important libraries**

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns
from google.colab import drive

# %% [markdown]
# **Read the file**
#
# It is lot more easier to read the file directly from your system using the below syntax, especially when you don;t have all of your data files sitting within the Python root folder.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-115291d1-c0ca-4dea-8d21-97087571d352" name="files[]" multiple disabled />
#      <output id="result-115291d1-c0ca-4dea-8d21-97087571d352">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data (4).csv

# %% [markdown]
# **Read the first 20 records**
# It is always a good idea to check how the imported data looks like. I have used the df.head command to read the first 20 records within my data.

# %%
df = pd.read_csv('data.csv')
df.head(20)
# Out:
#     Saves  Competitor_Credit  Discount Service Call  Free Equipment  Sentiment
# 0    1361                268                     43              12         -3
# 1     490                 99                      8               9          5
# 2    1925                413                     56              15          1
# 3    1494                329                     49              18          7
# 4    1367                287                     38               8          6
# 5     813                264                     40              19         -3
# 6     527                283                     49              12         -3
# 7     187                101                     27               6         -1
# 8     640                346                     49              11         10
# 9     438                257                     51              22          9
# 10    453                294                     43              12          0
# ...

# %% [markdown]
# **Understand the data type**
#
# To be able to slice and dice data effeciently, it is important to know the data types. Hence, "datatypes" command to understand the data class whether it is a boolean, integer, float, string etc.

# %%
df.dtypes
# Out:
# Saves                    int64
# Competitor_Credit        int64
# Discount Service Call    int64
# Free Equipment           int64
# Sentiment                int64
# dtype: object

# %% [markdown]
# **Describe the data**
#
# Pandas describe command can be used to view some basic statistical details like percentile, mean, std etc. of a data frame or a series of numeric values.

# %%
df.describe()
# Out:
#              Saves  Competitor_Credit  ...  Free Equipment  Sentiment
# count    64.000000          64.000000  ...       64.000000  64.000000
# mean    562.890625         178.734375  ...       10.953125   3.359375
# std     311.940578          89.997221  ...        5.352435   4.325514
# min     142.000000          26.000000  ...        0.000000  -3.000000
# 25%     447.750000         102.500000  ...        7.000000   0.000000
# 50%     540.000000         166.500000  ...       10.000000   2.500000
# 75%     640.000000         254.000000  ...       15.000000   7.250000
# max    1925.000000         413.000000  ...       24.000000  10.000000
#
# [8 rows x 5 columns]

# %% [markdown]
# **Understanding the Data Spread**
#
#  Histogram shows basic information about the data set, such as central location , width of spread , and shape.

# %%
df['Sentiment'].plot(kind='hist', bins=5)

# %% [markdown]
# **Stripplots**
#
# A strip plot is a scatter plot where one of the variables is categorical. They can be combined with other plots to provide additional information. However, in the below graph we are just looking at two continuous variables.
#
# This plot can be made more telling and intuitive by combining it with a boxplot because it makes additional information apprent about how the underlying data is distributed relative to the other datafield.

# %%
sns.set(style ="darkgrid") 
ax = sns.stripplot(x = 'Competitor_Credit', y = 'Sentiment', data = df)

# %% [markdown]
# **Violin Plot**
#
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.

# %%
sns.violinplot(x="Sentiment",y="Free Equipment",data=df)

# %% [markdown]
# **Catplot**
#
# This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations. The kind parameter selects the underlying axes-level function to use:
#
# **Categorical scatterplots:**
#
# stripplot() (with kind="strip"; the default)
# swarmplot() (with kind="swarm")
#
# **Categorical distribution plots:**
# boxplot() (with kind="box")
# violinplot() (with kind="violin")
# boxenplot() (with kind="boxen")
#
# **Categorical estimate plots:**
# pointplot() (with kind="point")
# barplot() (with kind="bar")
# countplot() (with kind="count")

# %%
sns.catplot("Sentiment","Discount Service Call", data=df,kind="bar",height=5, aspect=2, palette="muted",legend=True)

# %% [markdown]
# **Boxplot**
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.boxplot("Sentiment", data=df)

# %% [markdown]
# **Pairplot**
#
# Plots pairwise relationships in a dataset, draw scatterplots for joint relationships and histograms for univariate distributions. Below chart shows the linear regression model to the scatter plots using kind as "reg"

# %%
sns.pairplot(df, kind="reg",palette="husl")
fig.suptitle("Pair Plots of Key Variables", y=1.08)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-afde0ab17739> in <module>()
#       1 sns.pairplot(df, kind="reg",palette="husl")
# ----> 2 fig.suptitle("Pair Plots of Key Variables", y=1.08)
#
# NameError: name 'fig' is not defined

# %% [markdown]
# **Joint Grid Plots**
#
# Draw a bivariate plot of x and y.
#
# **Parameters:	**
# func : plotting callable
#
# This must take two 1d arrays of data as the first two positional arguments, and it must plot on the “current” axes.
#
# kwargs : key, value mappings
#
# Keyword argument are passed to the plotting function.
#
# Returns:
# self : JointGrid instance
#
# Returns self.

# %%
sns.set(style="darkgrid", color_codes=True)
sns.jointplot(x=df["Sentiment"],y=df["Saves"], kind='scatter',s=300, color='crimson', edgecolor="gold", linewidth=2)

# %%
sns.jointplot(x=df["Sentiment"],y=df["Saves"], kind='reg')

# %%
sns.regplot(x=df["Saves"],y=df["Free Equipment"], line_kws={"color":"darkgreen","alpha":0.8,"lw":2})
sns.regplot(x=df["Saves"],y=df["Discount Service Call"], line_kws={"color":"m","alpha":0.8,"lw":2})
sns.regplot(x=df["Saves"],y=df["Sentiment"], line_kws={"color":"gold","alpha":0.8,"lw":2})

# %%
sns.heatmap(df.corr(), annot=True)
